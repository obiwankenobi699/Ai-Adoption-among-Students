# %%
from ydata_profiling import ProfileReport
import pandas as pd

# %%
df = pd.read_csv(r'assets/ai_assistant_usage_student_life.csv')

# %%
df

# %%
profile = ProfileReport(df,title="Ai_Adoption",explorative=True)

# %%
profile.to_file("assets/ai_assistant_usage_student_life.html")
